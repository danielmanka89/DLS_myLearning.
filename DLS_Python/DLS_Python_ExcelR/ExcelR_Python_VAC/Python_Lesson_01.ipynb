# %%
x = 10 

# Anything after # is a comment and is ignored by Python
# Here we define a variable x and assign it the value 10
# use shift + enter to run the code

x
# Here we output the value of x
# Out:
# 10

# %%
# We can also use the print function to display the value of x

print(x)
# Out:
# 10

# %%
# To check the type of a variable, we can use the type() function

type(x)
# Out:
# int

# %%
a=10
print(a)
# Out:
# 10
